# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A15-E247
#
#  Directory of C:\Users\Admin\Documents\Excelr\Assignment\1.Basic Statistics Level - 1\Q.9_a
#
# 06/17/2022  09:30 PM    <DIR>          .
# 06/17/2022  09:30 PM    <DIR>          ..
# 06/17/2022  09:30 PM    <DIR>          .ipynb_checkpoints
# 02/27/2022  10:51 PM               502 Q9_a.csv
# 05/15/2022  02:15 PM            66,457 Q-9_a.ipynb
#                2 File(s)         66,959 bytes
#                3 Dir(s)  25,517,322,240 bytes free

# %%
cars_data = pd.read_csv('Q9_a.csv')

# %%
cars_data
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
cars_data = cars_data[['speed' , 'dist']]

# %%
cars_data.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
cars_data.apply(np.min)
# Out:
# speed    4
# dist     2
# dtype: int64

# %%
cars_data.apply(np.max)
# Out:
# speed     25
# dist     120
# dtype: int64

# %%
cars_data.shape
# Out:
# (50, 2)

# %%
cars_data.set_index('speed')
# Out:
#        dist
# speed
# 4         2
# 4        10
# 7         4
# 7        22
# 8        16
# 9        10
# 10       18
# 10       26
# 10       34
# 11       17
# 11       28
# 12       14
# 12       20
# 12       24
# 12       28
# 13       26
# 13       34
# 13       34
# 13       46
# 14       26
# 14       36
# 14       60
# 14       80
# 15       20
# 15       26
# 15       54
# 16       32
# 16       40
# 17       32
# 17       40
# 17       50
# 18       42
# 18       56
# 18       76
# 18       84
# 19       36
# 19       46
# 19       68
# 20       32
# 20       48
# 20       52
# 20       56
# 20       64
# 22       66
# 23       54
# 24       70
# 24       92
# 24       93
# 24      120
# 25       85

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
plt.plot(cars_data.dist);
plt.xlabel('speed');
plt.ylabel('dist');
# Out:
# C:\Users\Admin\Anacondanew3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sn.distplot(cars_data.speed, label = 'CARS');
plt.xlabel('speed');
plt.ylabel('dist');
plt.legend();

# %%
# !pip install scipy==1.6.0

# %%
#import the libraries
import pandas as pd 
import scipy
import numpy as np
from scipy import stats

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
skew(cars_data, bias=False)
# Out:
# array([-0.11750986,  0.80689496])

# %%
kurtosis(cars_data, bias=False)
# Out:
# array([-0.50899442,  0.40505258])
